# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
from matplotlib.image import imread
import os

# %%
dir_on = {
    'beat':'../dataset-baru/beat-nyala', 'bull':'../dataset-baru/bull-nyala', 'cbr':'../dataset-baru/cbr-nyala', 
    'mio':'../dataset-baru/mio-nyala', 'mio2':'../dataset-baru/mio2-nyala', 'scoopy':'../dataset-baru/scoopy-nyala', 
    'supra':'../dataset-baru/supra-nyala', 'beat_gelap':'../dataset-baru/beat-gelap-nyala/', 'cbr_gelap':'../dataset-baru/cbr-gelap-nyala/'
}

dir_off = {
    'beat':'../dataset-baru/beat-mati', 'bull':'../dataset-baru/bull-mati', 'cbr':'../dataset-baru/cbr-mati', 
    'mio':'../dataset-baru/mio-mati', 'mio2':'../dataset-baru/mio2-mati', 'scoopy':'../dataset-baru/scoopy-mati', 
    'supra':'../dataset-baru/supra-mati', 'beat_gelap':'../dataset-baru/beat-gelap-mati/', 'cbr_gelap':'../dataset-baru/cbr-gelap-mati/'
}

# %%
def iterateFiles(directory_path):
    # Iterate through all files and subdirectories in the given directory
    for root, _, files in os.walk(directory_path):
        n=0
        for filename in files:
            print(f'{directory_path}\t{filename}\t{n}')

# %%
on_keys = list(dir_on.keys())
off_keys = list(dir_off.keys())

print(on_keys)
# Out:
# ['beat', 'bull', 'cbr', 'mio', 'mio2', 'scoopy', 'supra', 'beat_gelap', 'cbr_gelap']

# %%
for i in on_keys:
    iterateFiles(dir_on[i])
# Out:
# ../dataset-baru/beat-nyala	0.jpg	0
# ../dataset-baru/beat-nyala	1.jpg	0
# ../dataset-baru/beat-nyala	10.jpg	0
# ../dataset-baru/beat-nyala	11.jpg	0
# ../dataset-baru/beat-nyala	12.jpg	0
# ../dataset-baru/beat-nyala	13.jpg	0
# ../dataset-baru/beat-nyala	14.jpg	0
# ../dataset-baru/beat-nyala	15.jpg	0
# ../dataset-baru/beat-nyala	16.jpg	0
# ../dataset-baru/beat-nyala	17.jpg	0
# ../dataset-baru/beat-nyala	18.jpg	0
# ../dataset-baru/beat-nyala	19.jpg	0
# ../dataset-baru/beat-nyala	2.jpg	0
# ../dataset-baru/beat-nyala	20.jpg	0
# ../dataset-baru/beat-nyala	21.jpg	0
# ../dataset-baru/beat-nyala	22.jpg	0
# ../dataset-baru/beat-nyala	23.jpg	0
# ../dataset-baru/beat-nyala	24.jpg	0
# ../dataset-baru/beat-nyala	25.jpg	0
# ../dataset-baru/beat-nyala	26.jpg	0
# ../dataset-baru/beat-nyala	27.jpg	0
# ../dataset-baru/beat-nyala	28.jpg	0
# ../dataset-baru/beat-nyala	29.jpg	0
# ../dataset-baru/beat-nyala	3.jpg	0
# ../dataset-baru/beat-nyala	30.jpg	0
# ../dataset-baru/beat-nyala	31.jpg	0
# ../dataset-baru/beat-nyala	32.jpg	0
# ../dataset-baru/beat-nyala	33.jpg	0
# ../dataset-baru/beat-nyala	34.jpg	0
# ../dataset-baru/beat-nyala	35.jpg	0
# ../dataset-baru/beat-nyala	36.jpg	0
# ../dataset-baru/beat-nyala	37.jpg	0
# ../dataset-baru/beat-nyala	38.jpg	0
# ../dataset-baru/beat-nyala	39.jpg	0
# ../dataset-baru/mio2-nyala	10.jpg	0
# ../dataset-baru/mio2-nyala	11.jpg	0
# ../dataset-baru/mio2-nyala	12.jpg	0
# ../dataset-baru/mio2-nyala	13.jpg	0
# ../dataset-baru/mio2-nyala	14.jpg	0
# ../dataset-baru/mio2-nyala	15.jpg	0
# ../dataset-baru/mio2-nyala	16.jpg	0
# ../dataset-baru/mio2-nyala	17.jpg	0
# ../dataset-baru/mio2-nyala	18.jpg	0
# ../dataset-baru/mio2-nyala	19.jpg	0
# ../dataset-baru/mio2-nyala	2.jpg	0
# ../dataset-baru/mio2-nyala	20.jpg	0
# ../dataset-baru/mio2-nyala	21.jpg	0
# ../dataset-baru/mio2-nyala	22.jpg	0
# ../dataset-baru/mio2-nyala	3.jpg	0
# ../dataset-baru/mio2-nyala	4.jpg	0
# ../dataset-baru/mio2-nyala	5.jpg	0
# ../dataset-baru/mio2-nyala	6.jpg	0
# ../dataset-baru/mio2-nyala	7.jpg	0
# ../dataset-baru/mio2-nyala	8.jpg	0
# ../dataset-baru/mio2-nyala	9.jpg	0
# ../dataset-baru/mio2-nyala	super.jpg	0
# ../dataset-baru/scoopy-nyala	0.jpg	0
# ../dataset-baru/scoopy-nyala	1.jpg	0
# ../dataset-baru/scoopy-nyala	10.jpg	0
# ../dataset-baru/scoopy-nyala	2.jpg	0
# ../dataset-baru/scoopy-nyala	3.jpg	0
# ../dataset-baru/scoopy-nyala	4.jpg	0
# ../dataset-baru/scoopy-nyala	5.jpg	0
# ../dataset-baru/scoopy-nyala	6.jpg	0
# ../dataset-baru/scoopy-nyala	7.jpg	0
# ../dataset-baru/scoopy-nyala	8.jpg	0
# ../dataset-baru/scoopy-nyala	9.jpg	0
# ../dataset-baru/scoopy-nyala	super.jpg	0
# ../dataset-baru/supra-nyala	0.jpg	0
# ../dataset-baru/supra-nyala	1.jpg	0
# ../dataset-baru/supra-nyala	10.jpg	0
# ../dataset-baru/supra-nyala	11.jpg	0
# ../dataset-baru/supra-nyala	12.jpg	0
# ../dataset-baru/supra-nyala	13.jpg	0
# ../dataset-baru/supra-nyala	14.jpg	0
# ../dataset-baru/supra-nyala	2.jpg	0
# ../dataset-baru/supra-nyala	3.jpg	0
# ../dataset-baru/supra-nyala	4.jpg	0
# ../dataset-baru/supra-nyala	5.jpg	0
# ../dataset-baru/supra-nyala	6.jpg	0
# ../dataset-baru/supra-nyala	7.jpg	0
# ../dataset-baru/supra-nyala	8.jpg	0
# ../dataset-baru/supra-nyala	9.jpg	0
# ../dataset-baru/supra-nyala	super.jpg	0
# ../dataset-baru/beat-gelap-nyala/	0.jpg	0
# ../dataset-baru/beat-gelap-nyala/	1.jpg	0
# ../dataset-baru/beat-gelap-nyala/	2.jpg	0
# ../dataset-baru/beat-gelap-nyala/	3.jpg	0
# ../dataset-baru/beat-gelap-nyala/	4.jpg	0
# ../dataset-baru/beat-gelap-nyala/	5.jpg	0
# ../dataset-baru/beat-gelap-nyala/	super.jpg	0
# ../dataset-baru/cbr-gelap-nyala/	0.jpg	0
# ../dataset-baru/cbr-gelap-nyala/	super.jpg	0
