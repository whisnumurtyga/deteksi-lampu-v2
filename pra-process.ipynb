# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
from matplotlib.image import imread
import os

# %%
dir_on = {
    'beat':'dataset-baru/beat-nyala', 'bull':'dataset-baru/bull-nyala', 'cbr':'dataset-baru/cbr-nyala', 
    'mio':'dataset-baru/mio-nyala', 'mio2':'dataset-baru/mio2-nyala', 'scoopy':'dataset-baru/scoopy-nyala', 
    'supra':'dataset-baru/supra-nyala', 'beat_gelap':'dataset-baru/beat-gelap-nyala/', 'cbr_gelap':'dataset-baru/cbr-gelap-nyala/'
}

dir_off = {
    'beat':'dataset-baru/beat-mati', 'bull':'dataset-baru/bull-mati', 'cbr':'dataset-baru/cbr-mati', 
    'mio':'dataset-baru/mio-mati', 'mio2':'dataset-baru/mio2-mati', 'scoopy':'dataset-baru/scoopy-mati', 
    'supra':'dataset-baru/supra-mati', 'beat_gelap':'dataset-baru/beat-gelap-mati/', 'cbr_gelap':'dataset-baru/cbr-gelap-mati/'
}

# %%
def rename_files_in_directory(directory_path):
    # Iterate through all files and subdirectories in the given directory
    for root, _, files in os.walk(directory_path):
        n=0
        for filename in files:
            # print(f'{files}-{filename}-{n}')
            # Construct the full path of the current file
            file_path = os.path.join(root, filename)

            # Check if the file exists
            if os.path.isfile(file_path):
                # Extract the file's extension (if it has one)
                file_name, file_extension = os.path.splitext(filename)
                if 'super' in file_name:
                    pass
                else:
                    # Create the new file name with the desired prefix and extension
                    new_filename = f"{n}{file_extension}"

                    # Construct the full path for the new file name
                    new_file_path = os.path.join(root, new_filename)
                    
                    # Check if the new file name already exists
                    if not os.path.exists(new_file_path):
                        os.rename(file_path, new_file_path)
                        print(f"Renamed '{file_path}' to '{new_file_path}'")
                    else:
                        print(f"File '{new_file_path}' already exists, skipping.")
                    n+=1

# %%
on_keys = list(dir_on.keys())
off_keys = list(dir_off.keys())

print(on_keys)
# Out:
# ['beat', 'bull', 'cbr', 'mio', 'mio2', 'scoopy', 'supra', 'beat_gelap', 'cbr_gelap']

# %%
for i in on_keys:
    rename_files_in_directory(dir_on[i])
# Out:
# File 'dataset-baru/beat-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\5.jpg' already exists, skipping.
# Renamed 'dataset-baru/beat-nyala\14.jpg' to 'dataset-baru/beat-nyala\6.jpg'
# File 'dataset-baru/beat-nyala\7.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\8.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\9.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\10.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\11.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\12.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\13.jpg' already exists, skipping.
# Renamed 'dataset-baru/beat-nyala\21.jpg' to 'dataset-baru/beat-nyala\14.jpg'
# File 'dataset-baru/beat-nyala\15.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\16.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\17.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\18.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\19.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\20.jpg' already exists, skipping.
# Renamed 'dataset-baru/beat-nyala\28.jpg' to 'dataset-baru/beat-nyala\21.jpg'
# File 'dataset-baru/beat-nyala\22.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\23.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\24.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\25.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\26.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\27.jpg' already exists, skipping.
# Renamed 'dataset-baru/beat-nyala\34.jpg' to 'dataset-baru/beat-nyala\28.jpg'
# File 'dataset-baru/beat-nyala\29.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\30.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\31.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\32.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\33.jpg' already exists, skipping.
# Renamed 'dataset-baru/beat-nyala\4.jpg' to 'dataset-baru/beat-nyala\34.jpg'
# File 'dataset-baru/beat-nyala\35.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\36.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\37.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\38.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\39.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\40.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\41.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\42.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\43.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\44.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\45.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\46.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\47.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\48.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\49.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\50.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\51.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\52.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\53.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\54.jpg' already exists, skipping.
# File 'dataset-baru/beat-nyala\55.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\6.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\7.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\8.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\9.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\10.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\11.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\12.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\13.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\14.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\15.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\16.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\17.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\18.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\19.jpg' already exists, skipping.
# File 'dataset-baru/bull-nyala\20.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/cbr-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/mio-nyala\6.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\6.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\7.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\8.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\9.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\10.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\11.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\12.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\13.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\14.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\15.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\16.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\17.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\18.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\19.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\20.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\21.jpg' already exists, skipping.
# File 'dataset-baru/mio2-nyala\22.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\6.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\7.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\8.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\9.jpg' already exists, skipping.
# File 'dataset-baru/scoopy-nyala\10.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\0.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\1.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\2.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\3.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\4.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\5.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\6.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\7.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\8.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\9.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\10.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\11.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\12.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\13.jpg' already exists, skipping.
# File 'dataset-baru/supra-nyala\14.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/0.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/1.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/2.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/3.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/4.jpg' already exists, skipping.
# File 'dataset-baru/beat-gelap-nyala/5.jpg' already exists, skipping.
# File 'dataset-baru/cbr-gelap-nyala/0.jpg' already exists, skipping.

# %%
for i in on_keys:
    rename_files_in_directory(dir_off[i])
# Out:
# Renamed 'dataset-baru/beat-mati\IMG_6349.jpg' to 'dataset-baru/beat-mati\0.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6350.jpg' to 'dataset-baru/beat-mati\1.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6351.jpg' to 'dataset-baru/beat-mati\2.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6352.jpg' to 'dataset-baru/beat-mati\3.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6353.jpg' to 'dataset-baru/beat-mati\4.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6354.jpg' to 'dataset-baru/beat-mati\5.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6355.jpg' to 'dataset-baru/beat-mati\6.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6356.jpg' to 'dataset-baru/beat-mati\7.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6357.jpg' to 'dataset-baru/beat-mati\8.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6358.jpg' to 'dataset-baru/beat-mati\9.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6359.jpg' to 'dataset-baru/beat-mati\10.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6360.jpg' to 'dataset-baru/beat-mati\11.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6361.jpg' to 'dataset-baru/beat-mati\12.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6362.jpg' to 'dataset-baru/beat-mati\13.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6363.jpg' to 'dataset-baru/beat-mati\14.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6364.jpg' to 'dataset-baru/beat-mati\15.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6365.jpg' to 'dataset-baru/beat-mati\16.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6366.jpg' to 'dataset-baru/beat-mati\17.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6367.jpg' to 'dataset-baru/beat-mati\18.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6368.jpg' to 'dataset-baru/beat-mati\19.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6369.jpg' to 'dataset-baru/beat-mati\20.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6370.jpg' to 'dataset-baru/beat-mati\21.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6371.jpg' to 'dataset-baru/beat-mati\22.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6372.jpg' to 'dataset-baru/beat-mati\23.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6373.jpg' to 'dataset-baru/beat-mati\24.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6374.jpg' to 'dataset-baru/beat-mati\25.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6375.jpg' to 'dataset-baru/beat-mati\26.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6376.jpg' to 'dataset-baru/beat-mati\27.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6377.jpg' to 'dataset-baru/beat-mati\28.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6378.jpg' to 'dataset-baru/beat-mati\29.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6379.jpg' to 'dataset-baru/beat-mati\30.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6380.jpg' to 'dataset-baru/beat-mati\31.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6381.jpg' to 'dataset-baru/beat-mati\32.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6382.jpg' to 'dataset-baru/beat-mati\33.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6383.jpg' to 'dataset-baru/beat-mati\34.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6384.jpg' to 'dataset-baru/beat-mati\35.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6385.jpg' to 'dataset-baru/beat-mati\36.jpg'
# Renamed 'dataset-baru/beat-mati\IMG_6386.jpg' to 'dataset-baru/beat-mati\37.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6764.jpg' to 'dataset-baru/bull-mati\0.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6765.jpg' to 'dataset-baru/bull-mati\1.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6766.jpg' to 'dataset-baru/bull-mati\2.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6767.jpg' to 'dataset-baru/bull-mati\3.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6769.jpg' to 'dataset-baru/bull-mati\4.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6770.jpg' to 'dataset-baru/bull-mati\5.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6771.jpg' to 'dataset-baru/bull-mati\6.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6772.jpg' to 'dataset-baru/bull-mati\7.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6773.jpg' to 'dataset-baru/bull-mati\8.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6774.jpg' to 'dataset-baru/bull-mati\9.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6775.jpg' to 'dataset-baru/bull-mati\10.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6776.jpg' to 'dataset-baru/bull-mati\11.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6777.jpg' to 'dataset-baru/bull-mati\12.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6778.jpg' to 'dataset-baru/bull-mati\13.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6779.jpg' to 'dataset-baru/bull-mati\14.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6780.jpg' to 'dataset-baru/bull-mati\15.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6781.jpg' to 'dataset-baru/bull-mati\16.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6782.jpg' to 'dataset-baru/bull-mati\17.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6783.jpg' to 'dataset-baru/bull-mati\18.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6784.jpg' to 'dataset-baru/bull-mati\19.jpg'
# Renamed 'dataset-baru/bull-mati\IMG_6785.jpg' to 'dataset-baru/bull-mati\20.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6679.jpg' to 'dataset-baru/cbr-mati\0.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6680.jpg' to 'dataset-baru/cbr-mati\1.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6681.jpg' to 'dataset-baru/cbr-mati\2.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6682.jpg' to 'dataset-baru/cbr-mati\3.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6684.jpg' to 'dataset-baru/cbr-mati\4.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6685.jpg' to 'dataset-baru/cbr-mati\5.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6686.jpg' to 'dataset-baru/cbr-mati\6.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6687.jpg' to 'dataset-baru/cbr-mati\7.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6688.jpg' to 'dataset-baru/cbr-mati\8.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6689.jpg' to 'dataset-baru/cbr-mati\9.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6690.jpg' to 'dataset-baru/cbr-mati\10.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6691.jpg' to 'dataset-baru/cbr-mati\11.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6692.jpg' to 'dataset-baru/cbr-mati\12.jpg'
# Renamed 'dataset-baru/cbr-mati\IMG_6693.jpg' to 'dataset-baru/cbr-mati\13.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6712.jpg' to 'dataset-baru/mio-mati\0.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6713.jpg' to 'dataset-baru/mio-mati\1.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6714.jpg' to 'dataset-baru/mio-mati\2.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6715.jpg' to 'dataset-baru/mio-mati\3.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6716.jpg' to 'dataset-baru/mio-mati\4.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6717.jpg' to 'dataset-baru/mio-mati\5.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6718.jpg' to 'dataset-baru/mio-mati\6.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6719.jpg' to 'dataset-baru/mio-mati\7.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6720.jpg' to 'dataset-baru/mio-mati\8.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6721.jpg' to 'dataset-baru/mio-mati\9.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6722.jpg' to 'dataset-baru/mio-mati\10.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6723.jpg' to 'dataset-baru/mio-mati\11.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6724.jpg' to 'dataset-baru/mio-mati\12.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6725.jpg' to 'dataset-baru/mio-mati\13.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6726.jpg' to 'dataset-baru/mio-mati\14.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6727.jpg' to 'dataset-baru/mio-mati\15.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6728.jpg' to 'dataset-baru/mio-mati\16.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6730.jpg' to 'dataset-baru/mio-mati\17.jpg'
# Renamed 'dataset-baru/mio-mati\IMG_6731.jpg' to 'dataset-baru/mio-mati\18.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6814.jpg' to 'dataset-baru/mio2-mati\0.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6815.jpg' to 'dataset-baru/mio2-mati\1.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6817.jpg' to 'dataset-baru/mio2-mati\2.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6818.jpg' to 'dataset-baru/mio2-mati\3.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6819.jpg' to 'dataset-baru/mio2-mati\4.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6820.jpg' to 'dataset-baru/mio2-mati\5.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6821.jpg' to 'dataset-baru/mio2-mati\6.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6822.jpg' to 'dataset-baru/mio2-mati\7.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6823.jpg' to 'dataset-baru/mio2-mati\8.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6824.jpg' to 'dataset-baru/mio2-mati\9.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6825.jpg' to 'dataset-baru/mio2-mati\10.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6826.jpg' to 'dataset-baru/mio2-mati\11.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6827.jpg' to 'dataset-baru/mio2-mati\12.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6828.jpg' to 'dataset-baru/mio2-mati\13.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6829.jpg' to 'dataset-baru/mio2-mati\14.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6830.jpg' to 'dataset-baru/mio2-mati\15.jpg'
# Renamed 'dataset-baru/mio2-mati\IMG_6831.jpg' to 'dataset-baru/mio2-mati\16.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6448.jpg' to 'dataset-baru/scoopy-mati\0.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6449.jpg' to 'dataset-baru/scoopy-mati\1.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6450.jpg' to 'dataset-baru/scoopy-mati\2.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6451.jpg' to 'dataset-baru/scoopy-mati\3.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6452.jpg' to 'dataset-baru/scoopy-mati\4.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6453.jpg' to 'dataset-baru/scoopy-mati\5.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6454.jpg' to 'dataset-baru/scoopy-mati\6.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6455.jpg' to 'dataset-baru/scoopy-mati\7.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6472.jpg' to 'dataset-baru/scoopy-mati\8.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6473.jpg' to 'dataset-baru/scoopy-mati\9.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6474.jpg' to 'dataset-baru/scoopy-mati\10.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6475.jpg' to 'dataset-baru/scoopy-mati\11.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6476.jpg' to 'dataset-baru/scoopy-mati\12.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6477.jpg' to 'dataset-baru/scoopy-mati\13.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6478.jpg' to 'dataset-baru/scoopy-mati\14.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6479.jpg' to 'dataset-baru/scoopy-mati\15.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6480.jpg' to 'dataset-baru/scoopy-mati\16.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6481.jpg' to 'dataset-baru/scoopy-mati\17.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6482.jpg' to 'dataset-baru/scoopy-mati\18.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6483.jpg' to 'dataset-baru/scoopy-mati\19.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6484.jpg' to 'dataset-baru/scoopy-mati\20.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6485.jpg' to 'dataset-baru/scoopy-mati\21.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6486.jpg' to 'dataset-baru/scoopy-mati\22.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6487.jpg' to 'dataset-baru/scoopy-mati\23.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6488.jpg' to 'dataset-baru/scoopy-mati\24.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6489.jpg' to 'dataset-baru/scoopy-mati\25.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6490.jpg' to 'dataset-baru/scoopy-mati\26.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6491.jpg' to 'dataset-baru/scoopy-mati\27.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6492.jpg' to 'dataset-baru/scoopy-mati\28.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6493.jpg' to 'dataset-baru/scoopy-mati\29.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6494.jpg' to 'dataset-baru/scoopy-mati\30.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6495.jpg' to 'dataset-baru/scoopy-mati\31.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6496.jpg' to 'dataset-baru/scoopy-mati\32.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6497.jpg' to 'dataset-baru/scoopy-mati\33.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6498.jpg' to 'dataset-baru/scoopy-mati\34.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6499.jpg' to 'dataset-baru/scoopy-mati\35.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6500.jpg' to 'dataset-baru/scoopy-mati\36.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6501.jpg' to 'dataset-baru/scoopy-mati\37.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6502.jpg' to 'dataset-baru/scoopy-mati\38.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6503.jpg' to 'dataset-baru/scoopy-mati\39.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6504.jpg' to 'dataset-baru/scoopy-mati\40.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6505.jpg' to 'dataset-baru/scoopy-mati\41.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6506.jpg' to 'dataset-baru/scoopy-mati\42.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6507.jpg' to 'dataset-baru/scoopy-mati\43.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6508.jpg' to 'dataset-baru/scoopy-mati\44.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6509.jpg' to 'dataset-baru/scoopy-mati\45.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6510.jpg' to 'dataset-baru/scoopy-mati\46.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6511.jpg' to 'dataset-baru/scoopy-mati\47.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6512.jpg' to 'dataset-baru/scoopy-mati\48.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6513.jpg' to 'dataset-baru/scoopy-mati\49.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6514.jpg' to 'dataset-baru/scoopy-mati\50.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6515.jpg' to 'dataset-baru/scoopy-mati\51.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6516.jpg' to 'dataset-baru/scoopy-mati\52.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6517.jpg' to 'dataset-baru/scoopy-mati\53.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6518.jpg' to 'dataset-baru/scoopy-mati\54.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6519.jpg' to 'dataset-baru/scoopy-mati\55.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6520.jpg' to 'dataset-baru/scoopy-mati\56.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6521.jpg' to 'dataset-baru/scoopy-mati\57.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6522.jpg' to 'dataset-baru/scoopy-mati\58.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6523.jpg' to 'dataset-baru/scoopy-mati\59.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6524.jpg' to 'dataset-baru/scoopy-mati\60.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6525.jpg' to 'dataset-baru/scoopy-mati\61.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6526.jpg' to 'dataset-baru/scoopy-mati\62.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6527.jpg' to 'dataset-baru/scoopy-mati\63.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6528.jpg' to 'dataset-baru/scoopy-mati\64.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6529.jpg' to 'dataset-baru/scoopy-mati\65.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6530.jpg' to 'dataset-baru/scoopy-mati\66.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6531.jpg' to 'dataset-baru/scoopy-mati\67.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6532.jpg' to 'dataset-baru/scoopy-mati\68.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6533.jpg' to 'dataset-baru/scoopy-mati\69.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6534.jpg' to 'dataset-baru/scoopy-mati\70.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6535.jpg' to 'dataset-baru/scoopy-mati\71.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6536.jpg' to 'dataset-baru/scoopy-mati\72.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6537.jpg' to 'dataset-baru/scoopy-mati\73.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6538.jpg' to 'dataset-baru/scoopy-mati\74.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6539.jpg' to 'dataset-baru/scoopy-mati\75.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6540.jpg' to 'dataset-baru/scoopy-mati\76.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6541.jpg' to 'dataset-baru/scoopy-mati\77.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6542.jpg' to 'dataset-baru/scoopy-mati\78.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6543.jpg' to 'dataset-baru/scoopy-mati\79.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6544.jpg' to 'dataset-baru/scoopy-mati\80.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6546.jpg' to 'dataset-baru/scoopy-mati\81.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6547.jpg' to 'dataset-baru/scoopy-mati\82.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6548.jpg' to 'dataset-baru/scoopy-mati\83.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6549.jpg' to 'dataset-baru/scoopy-mati\84.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6550.jpg' to 'dataset-baru/scoopy-mati\85.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6551.jpg' to 'dataset-baru/scoopy-mati\86.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6552.jpg' to 'dataset-baru/scoopy-mati\87.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6553.jpg' to 'dataset-baru/scoopy-mati\88.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6554.jpg' to 'dataset-baru/scoopy-mati\89.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6555.jpg' to 'dataset-baru/scoopy-mati\90.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6556.jpg' to 'dataset-baru/scoopy-mati\91.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6557.jpg' to 'dataset-baru/scoopy-mati\92.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6558.jpg' to 'dataset-baru/scoopy-mati\93.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6559.jpg' to 'dataset-baru/scoopy-mati\94.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6560.jpg' to 'dataset-baru/scoopy-mati\95.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6561.jpg' to 'dataset-baru/scoopy-mati\96.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6562.jpg' to 'dataset-baru/scoopy-mati\97.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6563.jpg' to 'dataset-baru/scoopy-mati\98.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6564.jpg' to 'dataset-baru/scoopy-mati\99.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6565.jpg' to 'dataset-baru/scoopy-mati\100.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6566.jpg' to 'dataset-baru/scoopy-mati\101.jpg'
# Renamed 'dataset-baru/scoopy-mati\IMG_6567.jpg' to 'dataset-baru/scoopy-mati\102.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6850.jpg' to 'dataset-baru/supra-mati\0.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6851.jpg' to 'dataset-baru/supra-mati\1.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6852.jpg' to 'dataset-baru/supra-mati\2.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6853.jpg' to 'dataset-baru/supra-mati\3.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6854.jpg' to 'dataset-baru/supra-mati\4.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6855.jpg' to 'dataset-baru/supra-mati\5.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6856.jpg' to 'dataset-baru/supra-mati\6.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6858.jpg' to 'dataset-baru/supra-mati\7.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6859.jpg' to 'dataset-baru/supra-mati\8.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6860.jpg' to 'dataset-baru/supra-mati\9.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6861.jpg' to 'dataset-baru/supra-mati\10.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6862.jpg' to 'dataset-baru/supra-mati\11.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6863.jpg' to 'dataset-baru/supra-mati\12.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6864.jpg' to 'dataset-baru/supra-mati\13.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6865.jpg' to 'dataset-baru/supra-mati\14.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6866.jpg' to 'dataset-baru/supra-mati\15.jpg'
# Renamed 'dataset-baru/supra-mati\IMG_6867.jpg' to 'dataset-baru/supra-mati\16.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6570.jpg' to 'dataset-baru/beat-gelap-mati/0.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6571.jpg' to 'dataset-baru/beat-gelap-mati/1.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6572.jpg' to 'dataset-baru/beat-gelap-mati/2.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6573.jpg' to 'dataset-baru/beat-gelap-mati/3.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6574.jpg' to 'dataset-baru/beat-gelap-mati/4.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6575.jpg' to 'dataset-baru/beat-gelap-mati/5.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6576.jpg' to 'dataset-baru/beat-gelap-mati/6.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6577.jpg' to 'dataset-baru/beat-gelap-mati/7.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6578.jpg' to 'dataset-baru/beat-gelap-mati/8.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6579.jpg' to 'dataset-baru/beat-gelap-mati/9.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6580.jpg' to 'dataset-baru/beat-gelap-mati/10.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6581.jpg' to 'dataset-baru/beat-gelap-mati/11.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6582.jpg' to 'dataset-baru/beat-gelap-mati/12.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6583.jpg' to 'dataset-baru/beat-gelap-mati/13.jpg'
# Renamed 'dataset-baru/beat-gelap-mati/IMG_6584.jpg' to 'dataset-baru/beat-gelap-mati/14.jpg'
# Renamed 'dataset-baru/cbr-gelap-mati/IMG_6704.jpg' to 'dataset-baru/cbr-gelap-mati/0.jpg'
# Renamed 'dataset-baru/cbr-gelap-mati/IMG_6706.jpg' to 'dataset-baru/cbr-gelap-mati/1.jpg'
# Renamed 'dataset-baru/cbr-gelap-mati/IMG_6707.jpg' to 'dataset-baru/cbr-gelap-mati/2.jpg'
# Renamed 'dataset-baru/cbr-gelap-mati/IMG_6708.jpg' to 'dataset-baru/cbr-gelap-mati/3.jpg'
# Renamed 'dataset-baru/cbr-gelap-mati/IMG_6709.jpg' to 'dataset-baru/cbr-gelap-mati/4.jpg'
